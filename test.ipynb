# %%
# coding: utf-8

import pandas as pd 
import numpy as np
import time
import json

if __name__ == '__main__':
    np.set_printoptions(threshold=np.inf)
    ob = json.loads(open('/kywk/strategy/strange/future/142/ag1608/ag1608_20160809.jcsv', 'r+').read())
    dt = ob.get('dt')
    for t in dt:
        print t.get('vl')
        print time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(int(t.get('ct'))))
    #df = pd.read_csv('./data/ag1601_2016-1-4_2016-1-15.jcsv', sep = ',' )
    #indest = df.index
    ##df_close = pd.Series(df['close'].tolist(), index = indest)
    #df_high = pd.Series(df['high'].tolist(), index = indest)
    #df_low = pd.Series(df['low'].tolist(), index = indest)
    
    #lc_array = np.array(df_close[:-1])
    #close_array = np.array(df_close[1:])
    #high_array = np.array(df_high[1:])
    #low_array = np.array(df_low[1:])
    #dif_array =  \
     #   close_array - np.where(close_array > lc_array,
      #                         np.minimum(low_array,lc_array),
       #                        np.maximum(high_array,lc_array))
    
    #print dif_array
    #print len(dif_array)
    #print dif_array.sum() / len(dif_array)
    #print np.array(low_array)
    #print np.array(lc_array)
    #print np.minimum(np.array(low_array), np.array(lc_array))
    #print np.maximum(np.array(high_array), np.array(lc_array))
    #print np.where(close_array > lc_array,np.maximum(high_array - low_array,lc_array - low_array),0)
    #print np.where(close_array > lc_array, high_array, np.where(high_array < lc_array, lc_array,high_array))
# Out:
# 0
# 2016-08-08 21:00:01
# 0
# 2016-08-08 20:59:00
# 0
# 2016-08-08 21:00:01
# 0
# 2016-08-08 21:00:00
# 0
# 2016-08-08 21:00:01
# 0
# 2016-08-08 21:00:00
# 0
# 2016-08-08 21:00:01
# 0
# 2016-08-08 21:01:13
# 0
# 2016-08-08 21:00:53
# 0
# 2016-08-08 21:01:15
# 0
# 2016-08-08 21:01:42
# 0
# 2016-08-08 21:01:23
# 0
# 2016-08-08 21:01:42
# 0
# 2016-08-08 21:01:43
# 0
# 2016-08-08 21:01:42
# 0
# 2016-08-08 21:01:43
# 0
# 2016-08-08 21:01:23
# 0
# 2016-08-08 21:01:42
# 0
# 2016-08-08 21:01:43
# 0
# 2016-08-08 21:01:42
# 0
# 2016-08-08 21:01:43
# 0
# 2016-08-08 21:01:50
# 0
# 2016-08-08 21:01:48
# 0
# 2016-08-08 21:01:50
# 0
# 2016-08-08 21:03:02
# 0
# 2016-08-08 21:01:50
# 0
# 2016-08-08 21:03:02
# 0
# 2016-08-08 21:03:07
# 0
# 2016-08-08 21:03:02
# 0
# 2016-08-08 21:03:07
# 0
# 2016-08-08 21:03:35
# 0
# 2016-08-08 21:03:34
# 0
# 2016-08-08 21:03:35
# 0
# 2016-08-08 21:03:34
# 0
# 2016-08-08 21:03:35
# 0
# 2016-08-08 21:03:37
# 0
# 2016-08-08 21:03:34
# 0
# 2016-08-08 21:03:35
# 0
# ...
